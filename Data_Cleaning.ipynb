# %%
import pandas as pd
import numpy as np

# %%
file_path = 'us_donations_2024.csv'

# %%
df = pd.read_csv(file_path)

# %%
df.sample(5)
# Out:
#            Donor Name                    Email                Phone  \
# 1256     Taylor Lopez  lambheather@example.net    (999)706-2265x238
# 1534  Jennifer Flores       troy71@example.net      +1-796-240-2331
# 715     Barry Sanchez       wbrown@example.net      +1-280-917-8793
# 1305       Paul Jones  lopezrobert@example.net  (708)287-0158x92426
# 23       Karen Garcia       lori14@example.net     905-339-1161x476
#
#       Donation Amount (USD) Donation Type          Project        Date  \
# 1256                1146.44       Sadaqah  Feed the Hungry  2024-06-20
# 1534               39958.70       Sadaqah      Medical Aid  2024-05-08
# 715                 2742.70       Qurbani      Medical Aid  2024-06-14
# 1305                 973.77         Zakat      Medical Aid  2024-03-07
# 23                  3931.42       Qurbani  Orphan Children  2024-01-28
#
#                        Location Payment Method  \
# 1256       Connerborough, Texas           Card
# 1534        East Vicki, Georgia      Apple Pay
# 715           East Janice, Ohio  Bank Transfer
# 1305   Port Tracystad, Illinois         PayPal
# 23    West Monicaburgh, Georgia           Card
#
#                                                   Notes
# 1256                      Whether court security young.
# 1534                          Charge share expect less.
# 715                 Responsibility film within support.
# 1305  Hair you prepare scene drive executive first a...
# 23            Management television eat expect evening.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Donor Name             2500 non-null   object
#  1   Email                  2238 non-null   object
#  2   Phone                  2500 non-null   object
#  3   Donation Amount (USD)  2500 non-null   float64
#  4   Donation Type          2500 non-null   object
#  5   Project                2500 non-null   object
#  6   Date                   2500 non-null   object
#  7   Location               2500 non-null   object
#  8   Payment Method         2500 non-null   object
#  9   Notes                  2500 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 195.4+ KB

# %%
currency = "BDT" if "bdt" in file_path.lower() or "bangladesh" in file_path.lower() else "USD"
amount_col = [col for col in df.columns if "donation amount" in col.lower()][0]

# %%
df['Email'] = df['Email'].fillna('No email provided').str.lower().str.strip()

# %%
df['Donation Type'] = df['Donation Type'].str.strip().str.capitalize()

# %%
df['Project'] = df['Project'].str.replace(r'\s+', ' ', regex=True).str.strip().str.title()

# %%
df['Project'].unique()
# Out:
# array(['Orphan Children', 'Feed The Hungry', 'Medical Aid',
#        'Homeless Shelter', 'Back To School Kits',
#        'Back To School Kits Want', 'Homeless Shelter Avoid',
#        'Feed The Hungry Anything', 'Feed The Hungry Century',
#        'Medical Aid Quality', 'Homeless Shelter Choice',
#        'Homeless Shelter Present', 'Orphan Children Go',
#        'Homeless Shelter War', 'Feed The Hungry Home',
#        'Homeless Shelter Whole', 'Back To School Kits Morning',
#        'Medical Aid Chance', 'Medical Aid Near', 'Medical Aid Score',
#        'Homeless Shelter Right', 'Orphan Children Result',
#        'Back To School Kits Technology', 'Medical Aid Interesting',
#        'Homeless Shelter Writer', 'Homeless Shelter Join',
#        'Orphan Children Around', 'Homeless Shelter Actually',
#        'Homeless Shelter Provide', 'Homeless Shelter Military',
#        'Homeless Shelter Song', 'Homeless Shelter Gas',
#        'Medical Aid Even', 'Medical Aid Tough', 'Homeless Shelter Simple',
#        'Orphan Children Sign', 'Orphan Children Half',
#        'Back To School Kits Understand', 'Back To School Kits Drive',
#        'Orphan Children Window', 'Back To School Kits Past',
#        'Back To School Kits Should', 'Orphan Children Project',
#        'Orphan Children Box', 'Feed The Hungry How',
#        'Back To School Kits Man', 'Feed The Hungry Yes',
#        'Orphan Children Bit', 'Orphan Children Rule',
#        'Feed The Hungry Movement', 'Feed The Hungry Laugh',
#        'Medical Aid Town', 'Feed The Hungry Spend',
#        'Orphan Children Data', 'Feed The Hungry Others',
#        'Orphan Children Decade', 'Homeless Shelter Enough',
#        'Back To School Kits Race', 'Orphan Children Bill',
#        'Feed The Hungry Reflect', 'Feed The Hungry Generation',
#        'Orphan Children Sometimes', 'Back To School Kits Middle',
#        'Back To School Kits Character', 'Back To School Kits Republican',
#        'Medical Aid Suggest', 'Orphan Children Age',
#        'Homeless Shelter Recently', 'Back To School Kits Pretty',
#        'Homeless Shelter Style', 'Back To School Kits Form',
#        'Orphan Children Let', 'Back To School Kits Hold',
#        'Back To School Kits Both', 'Back To School Kits Whatever',
#        'Orphan Children Attorney', 'Feed The Hungry Yet',
#        'Orphan Children Store', 'Feed The Hungry Admit',
#        'Medical Aid Recognize', 'Back To School Kits Tax',
#        'Homeless Shelter Focus', 'Back To School Kits Front',
#        'Homeless Shelter System', 'Back To School Kits Face',
#        'Feed The Hungry Firm', 'Back To School Kits Small',
#        'Homeless Shelter Since', 'Homeless Shelter News',
#        'Back To School Kits Outside', 'Back To School Kits Director',
#        'Medical Aid Owner', 'Back To School Kits Cell',
#        'Back To School Kits Since', 'Orphan Children Difference',
#        'Medical Aid Society', 'Back To School Kits Itself',
#        'Feed The Hungry Each', 'Orphan Children Whole',
#        'Orphan Children Top', 'Back To School Kits Fire',
#        'Orphan Children Radio', 'Feed The Hungry Would',
#        'Medical Aid Partner', 'Orphan Children Wind',
#        'Medical Aid Camera', 'Feed The Hungry Land',
#        'Back To School Kits Mrs', 'Feed The Hungry Various',
#        'Feed The Hungry Born', 'Back To School Kits Responsibility',
#        'Feed The Hungry Raise', 'Homeless Shelter Religious',
#        'Back To School Kits Three', 'Orphan Children Floor',
#        'Homeless Shelter Establish', 'Medical Aid Just',
#        'Feed The Hungry Grow', 'Orphan Children History',
#        'Back To School Kits Main', 'Homeless Shelter Energy',
#        'Medical Aid Start', 'Medical Aid Exactly', 'Medical Aid Pretty',
#        'Homeless Shelter Various', 'Medical Aid Positive',
#        'Homeless Shelter Television', 'Medical Aid Own',
#        'Medical Aid Three'], dtype=object)

# %%
# !pip install rapidfuzz
# Out:
# Collecting rapidfuzz
#   Downloading rapidfuzz-3.13.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Downloading rapidfuzz-3.13.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 26.3 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz
# Successfully installed rapidfuzz-3.13.0

# %%
from rapidfuzz import process

valid_projects = ['Orphan Children', 'Feed the Hungry', 'Homeless Shelter', 'Medical Aid', 'Back to School Kits', 'Rohingya Refugee Support', 'Medical Care', 'Eid Gifts For Children']

def match_project(proj_name):
    match, score, _ = process.extractOne(proj_name, valid_projects)
    return match if score > 80 else proj_name

df['Project'] = df['Project'].apply(match_project)

# %%
df['Project'].unique()
# Out:
# array(['Orphan Children', 'Feed the Hungry', 'Medical Aid',
#        'Homeless Shelter', 'Back to School Kits'], dtype=object)

# %%
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
# df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
# df['Day'] = df['Date'].dt.day

# %%
df = df.drop_duplicates()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2381 entries, 0 to 2380
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Donor Name             2381 non-null   object
#  1   Email                  2381 non-null   object
#  2   Phone                  2381 non-null   object
#  3   Donation Amount (USD)  2381 non-null   float64
#  4   Donation Type          2381 non-null   object
#  5   Project                2381 non-null   object
#  6   Date                   2381 non-null   datetime64[ns]
#  7   Location               2381 non-null   object
#  8   Payment Method         2381 non-null   object
#  9   Notes                  2381 non-null   object
#  10  Month                  2381 non-null   int32
# dtypes: datetime64[ns](1), float64(1), int32(1), object(8)
# memory usage: 213.9+ KB

# %%
threshold = df[amount_col].quantile(0.95)
df = df[df[amount_col] <= threshold]

# %%
df['Phone'] = df['Phone'].astype(str).str.replace(r'\D', '', regex=True)
df['Phone'] = df['Phone'].apply(lambda x: f"+880{x[-10:]}" if currency == "BDT" else f"+1{x[-10:]}" if len(x) >= 10 else "Invalid")

# %%
df['Payment Method'] = df['Payment Method'].str.strip().str.title()
if currency == "BDT":
    allowed_pm = ['Bkash', 'Nagad', 'Bank Transfer', 'Card']
else:
    allowed_pm = ['Card', 'Bank Transfer', 'Paypal', 'Apple Pay']
df['Payment Method'] = df['Payment Method'].apply(
    lambda x: x if x in allowed_pm else 'Other'
)

# %%
df['Notes'] = df['Notes'].astype(str).str.replace(r'\s+', ' ', regex=True).str.strip()

# %%
df['Location'] = df['Location'].str.title().str.strip()

# %%
df.rename(columns={amount_col: f'Donation Amount ({currency})'}, inplace=True)

# %%
df.head()
# Out:
#           Donor Name                     Email         Phone  \
# 0       Grace Foster  carloconnell@example.com  +13989717117
# 1       Seth Jackson      george37@example.org  +18857124596
# 2  Kimberly Morrison     cynthiali@example.com  +13306537445
# 3      Michael Davis     jeffrey04@example.net  +19357583995
# 4      Michael Rojas  wrightjustin@example.org  +12482146024
#
#    Donation Amount (USD) Donation Type           Project       Date  \
# 0                3493.24         Zakat   Orphan Children 2024-06-05
# 1                 806.16       Sadaqah   Feed the Hungry 2024-12-22
# 2                2176.76         Fidya       Medical Aid 2024-10-13
# 3                1510.32         Fidya   Orphan Children 2024-03-11
# 4                4246.96       Qurbani  Homeless Shelter 2024-06-07
#
#                      Location Payment Method  \
# 0  New Rachel, North Carolina  Bank Transfer
# 1   Carterchester, California  Bank Transfer
# 2      Princeborough, Georgia      Apple Pay
# 3      South Thomas, New York         Paypal
# 4      New Joseph, California  Bank Transfer
#
#                                                Notes  Month
# 0                           Before method edge hand.      6
# 1  Face final month college improve analysis seve...     12
# 2                          Her dream feeling player.     10
# 3                               Sing know newspaper.      3
# 4     Mr dog simple laugh especially during mention.      6

# %%
df.to_csv(f'cleaned_{file_path}', index=False)
